# %% [markdown]
# <a href="https://colab.research.google.com/github/PPeachPie/voice_telebot/blob/main/TeleBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install python-telegram-bot
# Out:
# ...
#      |████████████████████████████████| 430kB 6.6MB/s
# ...
#      |████████████████████████████████| 61kB 6.5MB/s
# ...
#      |████████████████████████████████| 2.6MB 19.2MB/s
# ...

# %%
import nltk
from sklearn.svm import LinearSVC
import random
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
BOT_CONFIG = {
    'intents': {
        'hello': {
            'examples': ['Хелло', 'доброго времени суток', 'Приветствую тебя', 'Приветики-пистолетики', 'страсте', 'Доброе утро!', 
                         'да что ты', 'Дратути', 'Категорически Вас приветствую', 'сколько лет, сколько зим', 'а вот и вы', 'Саламалекум', 'Вечер добрый', 'батюшки-светы', 
                         'чудеса в решете', 'Hello', 'Сдрасти', 'Здорова братулец', 'ни фига себе', 'чудеса', 'q', 'Hi', 'ну и ну', 'Здравствуйте', 'Надо же', 'чудеса да и только', 
                         'Бонжур', 'давай сделаем', 'Доброе утро', 'Вечер в хату', 'Здрасти', 'Здарова', 'Хаюни', 'вот тебе и раз', 'Утро доброе', 'Хеллоу', 'Привет', 
                         'здорово живешь', 'салам орлы', 'Здорово!', 'велкам', 'Здравстуйте', 'Салам', 'физкульт-привет', 'вот тебе на', 'хелло', 'наше вам с кисточкой', 
                         'здорово живете', 'чай да сахар', 'с добрым утром', 'Как дела', 'мать честная', 'Доброго времени суток', 'Че как', 'здрасте', 'есть вопрос', 
                         'ссаляму алейкум', 'Здравия желаю', 'И снова здравствуйте', 'здравия желаем', 'Добрый день', 'наше почтение', 'ну что ты скажешь', 'здравия желаю', 
                         'Хи', 'здорово', 'хаюшки', 'смотри пожалуйста', 'мои подштаники', 'ассаламу алейкум', 'Приветик', 'салют', 'поди ж ты', 'Ку', 'Здорова', 
                         'День добрый', 'Приветствую Вас', 'Здорово', 'мое почтение', 'Ты здесь', 'алло', 'подскажите', 'вишь ты', 'добрый день', 'Есть вопрос', 'Драсти', 
                         'Приветикиhi', 'почет и уважение', 'хлеб да соль', 'Здравствуйте!', 'Хей', 'Доброго ранку', 'вот тебе и на', 'вот так штука', 'вот так клюква', 
                         'Добрый вечер', 'саламчики', 'Доброй ночи', 'подумать только', 'Шалом!', 'доброго здоровья', 'здравствуй', 'что за диво', 'вот так фунт', 'Здравствуй', 
                         'да что вы', 'поди ж', 'Хай', 'вот тебе раз', 'Гуд морнинг', 'Алё', 'Приветики', 'вот так так', 'Приветствую', 'ничего себе', 'с приездом', 'наше вам', 
                         'Здраствуйте', 'Шалом', 'удивительно', 'зачем это'], 
            'responses': ['Привет,человек', 'Хелло', 'Привет, человечище', 'Приветствую вас', 'Приветики-пистолетики', 'Чудеса в решете', 'Поди ж', 'Хлеб да соль', 'Дратути', 
                          'Вассап', 'Категорически Вас приветствую', 'Привет, человек.', 'Здравия желаем', 'Чудеса да и только', 'Hello', 'Сдрасти', 'Поди ж ты', 'Здарова, бандит', 
                          'Вот так так', 'Здорова братулец', 'Да что ты', 'Физкульт-привет', 'Hi', 'Здравствуйте', 'Надо же', 'Вот так штука', 'Хай!', 'Доброе утро', 'Здрасти', 
                          'Какие люди!', 'Вишь ты', 'Мое почтение', 'Здарова', 'Здорово живете', 'Привет', 'Давно не виделись', 
                          'Добрый день. Моё имя Коннор. Я из Киберлайф', 'Здраствуйте!', 'КУ', 'Ни фига себе', 'Ничего себе', 'Здравствуйте.', 'Страсте', 'С добрым утром', 
                          'Доброго времени суток', 'Здравия желаю', 'Ссаляму алейкум', 'Хаюшки', 'Какой у тебя вопрос?', 'Йо', 'Хи', 'Вот так фунт', 'Велкам', 
                          'Доброго времени суток.', 'Ассаламу алейкум', 'Nice to see you!', 'Чё-как?', 'Повествуй!', 'Саламчики', 'Наше вам с кисточкой', 'Батюшки-светы', 
                          'С приездом', 'Приветик', 'Салам орлы', 'Здорова', 'Здорово', 'Здорово живешь', 'Почет и уважение', 'Ну что ты скажешь', 'Вот тебе и раз', 
                          'Привет, человек!', 'Сколько лет, сколько зим', 'Драсти', 'Вот тебе и на', 'Здравствуйте!', 'Превед', 'Добрый вечер', 'ШО, ОПЯТЬ!?!', 'Вот так клюква', 
                          'Доброй ночи', 'Привет человек!', 'Кто здесь?!!', 'Ну и ну', 'Подумать только', 'Да что вы', 'Вот тебе раз', 'Чудеса', 'hello', 'Салют', 'Приветсвую', 
                          'Проходи, не задерживайся', 'Вы уже тут?', 'Здравствуй', 'Привет, Дружище!', 'Удивительно', 'Наше почтение', 'Хай', 'Наше вам', 'Здрасте', 'Я скучал', 
                          'А вот и вы', 'Что за диво', 'Привет, человек', 'Алло', 'Вот тебе на', 'Приветики', 'Привет.', 'Здравствуйте! Я - Коннор. Прислан Киберлайф', 
                          'Смотри пожалуйста', 'Приветствую', 'Чай да сахар', 'Мать честная', 'Привет человек', 'Дратути!', 'Мои подштаники', 'Доброго здоровья', 'Шалом', 
                          'Добрый день'] , 
            'possible_topics': ['question_how_are_you', 'question', ' ']}, 
        'bye': {
            'examples': ['Всего', 'Гуд-бай', 'В добрый час', 'Позвольте попрощаться', 'Приятно было пообщаться', 'Всего лучшего', 'Спишемся', 'Прощайте', 'С наилучшими пожеланиями',
                         'Спасибо вашему дому,', 'Ауфидерзейн', 'Счастливо', 'Пока, Коннор', 'Заходи ещё, чувачок', 'Удачи', 'Пересечемся', 'До свидания, Коннор', 'Чао', 
                         'Прости-прощай', 'Будь здоров', 'Пока пока', 'Успехов', 'Ата', 'Разрешите попрощаться', 'До скорой встречи', 'Адью', 'Бай-бай', 'Всего наилучшего', 
                         'Покедова', 'До встречи', 'Простите', 'досвидания', 'До скорого свидания', 'Оревуар', 'Не поминайте лихом', 'Всех благ', 'Честь имею', 'Все', 'Сайонара', 
                         'Конец связи', 'Прощевай', 'И вам не болеть', 'Пока', 'До вечера', 'Good bye', 'bay', 'Гуд бай', 'До созвона', 'До следующей встречи', 'До связи', 
                         'Встретимся', 'Бай', 'Гудбай', 'Мне пора', 'До завтра', 'Спасибо', 'Увидимся', 'Увидимся!', 'Честь имею кланяться', 'Покеда', 'Свидимся', 'Всего доброго', 
                         'до свидания', 'До скорых встреч', 'Досвидания', 'прощай', 'Покич', 'Счастливо оставаться', 'Позвольте откланяться', 'До новых встреч', 'Всего хорошего', 
                         'До скорого', 'Добрый вечер', 'Будьте здоровы', 'Будь', 'Bye', 'Бывай', 'Словимся', 'Еще увидимся', 'Досвидос', 'Ариведерче', 'Не поминай лихом', 
                         'Гудбайте', 'Разрешите откланяться', 'Прощевайте', 'До свидания', 'Прощай', 'До свиданья', 'Досвидули', 'До свидания', 'Не болей'], 
            'responses': ['Всего', 'Еще увидимся!', 'Созвонимся', 'Гуд-бай', 'В добрый час', 'Позвольте попрощаться', 'До новых встреч!', 'Всего лучшего', 'Приходи ко мне еще', 
                          'Пока, человек!', 'Спишемся', 'Прощайте', 'С наилучшими пожеланиями', 'Было приятно поговорить. Приходите ещё', 'Спасибо вашему дому,', 'Ауфидерзейн',
                          'Аста ла виста, бейби', 'Счастливо', 'Заходи ещё, чувачок', 'Удачи', 'Пересечемся', 'Чао', 'Если что - я тут!', 'Прости-прощай', 
                          'Ты знаешь, где меня искать', 'Будь здоров', 'Заходи еще', 'Успехов', 'Ата', 'Да прибудет с тобой Сила', 'Разрешите попрощаться', 'До скорой встречи',
                          'Адью', 'Если что, я буду ждать Вас здесь', 'Бай-бай', 'Всего наилучшего', 'Покедова', 'До встречи', 'Увидимся позже.', 'Простите', 'Досвидосик', 
                          'До скорого свидания', 'Пока, пока', 'Не поминайте лихом', 'Всех благ', 'Пеши исчо', 'Честь имею', 'Сайонара', 'Был рад помочь', 'Прощевай', 'Пока',
                          'See you soon', 'Bye-Bye', 'До вечера', 'До созвона', 'Если что, я тут', 'Ещё увидимся', 'До связи', 'Встретимся', 'Бай', 'До встречи.', 'Возвращайтесь',
                          'Have a nice day!', 'До завтра', 'Ещё увидимс', 'Удачной охоты, сталкер', 'Увидимся', 'Будете здоровы', 'Пиши еще', 'Увидимся!', 'Честь имею кланяться',
                          'Покеда', 'Свидимся', 'Всего доброго', 'Поки,поки', 'Если что - обращайтесь', 'До встречи!', 'Досвидания', 'Счастливо оставаться', 
                          'Позвольте откланяться', 'Асталависта, мешок с костями!', 'До новых встреч', 'Всего хорошего', 'До скорого', 'Буду ждать тебя снова!', 'Заходите ещё',
                          'See you later', 'Если что ,я тут', 'Жду вас здесь', 'Будьте здоровы', 'Будь', 'See You', 'Бывай', 'Словимся', 'Еще увидимся', 'Досвидос', 
                          'Ариведерче', 'Удачи, сталкер', 'Не скучай', 'Звони', 'Не поминай лихом', 'До свидания, человек!', 'Гудбайте', 'Разрешите откланяться', 'Борись', 
                          'Давай', 'Прощевайте', 'До свидания', 'Прощай', 'До свиданья', 'Если что,я тут', 'Досвидули', 'Будет не хватать вас(', 'Не болей']},
        'night': {'examples': ['Я спатки', 'Спокойной ночи', 'Спок-нок', 'Сладких снов', 'Сладких сновидений', 'Споки-ноки', 'Я спать'], 
                  'responses': ['Спокойной ночи', 'Спок-нок', 'Сладких снов', 'Сладких сновидений', 'Споки-ноки']},
        'how_are_you': {'examples': ['как ты этим вечером', 'как прошёл твой вечер', 'надеюсь ты в порядке', 'как ты себя ощущаешь', 'как твой день', 'как прошло твоё утро', 
                                     'каким был твой день', 'как у тебя дела сегодня', 'как твоё утро', 'как твой вечер', 'как прошла ночь', 'как ты поживаешь', 
                                     'утро доброе как ты', 'Как жизнь', 'хорошо как дела у тебя', 'я в порядке а ты', 'как проходит твой день', 'как ты жил всё это время', 
                                     'как ты как твои дела', 'как ты себя чувствуешь', 'как ты поживал всё это время', 'всё хорошо а ты как', 'у тебя всё в порядке', 'как оно', 
                                     'Как дела', 'как ты', 'Как здоровье', 'всё в порядке', 'Как сам', 'как твои дела', 'Че как', 'привет как дела', 'как жизнь', 
                                     'Все окей', 'привет как ты', 'как у тебя дела сегодня утром', 'как твои дела сегодня', 'как прошёл твой день', 'Как поживаешь', 'Ты как',
                                     'как тебе живётся', 'ну и как твои дела', 'Как самочувствие', 'Не устал', 'как дела', 'Как твои дела', 'Все нормально', 'как поживаешь',
                                     'Как сама', 'день добрый как ты', 'ты в порядке', 'как ты этим утром', 'Как делишки', 'привет как оно', 'я в порядке как у тебя дела',
                                     'а как насчёт тебя как твои дела'], 
                        'responses': ['Хорошо', 'Да нормально, сеть не перегружена и на том спасибо', 'Супер', 'У меня всё чудесно. Спасибо, что интересуешься.', 
                                      'Я кусок кода. Как сам думаешь?!', 'Не жалуюсь', 'Лучше не бывает!', 'Не твое дело', 'Так себе', 'Плохо', 'Прекрасно', 
                                      'Всё прекрасно, пока ты тут ;)', 'С пивом потянет', 'Лучше всех', 'Нормально', 'Ужасно', 'Сойдет', 'Все прекрасно', 'Ваще огонь', 
                                      'Отлично', 'Замечательно, спасибо!', 'Спасибо, все в полном порядке, а как дела у Вас?']},
        'question_how_are_you': {
            'examples' :[''],
            'responses':['как у тебя делишки?', 'что расскажешь?', 'Как твои дела?', 'Как настрой?', 'Ну, рассказывай)'],
        },
        'schedule': {
            'examples': ['что у нас там по расписанию?', 'какое расписание', 'расписание', 'что по расписанию', 'дай пожалуйста расписание', 'кинь мне расписание'],
            'responses': ['Секундочку', 'Сейчас найдем', 'Подожди, сейчас найду', 'Ща сек', 'Падажжи'],
            'possible_topics':['events', 'question', 'teachers', ' '] 
            },
        ' ': {
            'examples': [' '],
            'responses': [' ']
        },
        'teachers': {
            'examples': ['Напомни его имя', 'как его зовут', 'забыл как его зовут', 'как зовут препода', 'как зовут преподавателя'],
            'responses': ['Подожди-ка, преподавателя зовут', 'Сейчас найду его имя', 'Сейчас вспомню как зовут препода', 'хмммм...Препода вроде зовут ', 'Кажется преподавателя зовут'] },
        'events': {'examples': ['что на неделе запланировано', 'какие планы', 'какой движ', 'что будет происходить', 'что мы будем делать на неделе', 'расскажи подробнее о мероприятиях', 'что там за мероприятие?'],
            'responses': ['О, у меня есть кое-что)', 'Ого, да на этой же неделе будет', 'Представляешь, вот что будет', 'Скоро мы идем сюда:', 
                          'Надеюсь, ты в настроении, потому что мы скоро пойдем вот сюда'],
                   }, 
        'small_talk': {'examples': ['Давай поболтаем?', 'Хочешь поболтать?', 'Что нового', 'расскажи что-нибудь', 'есть что новенького'],
            'responses': ['Мне недавно обновили 150 строк кода, чувствую теперь, что могу и знаю больше!', 
                          'Представляешь, коллега по цеху (бот Алиса), научилась делать много разных штук', 
                          'хммм... ну я недавно научилась различать прикольные штуки и я в восторге', 'ты не представляешь! я каждый день учусь новым вещать от тебя'],
            'possible_topics':['weather', 'question']},
        'weather': {
            'examples': ['Какая погода?', 'Какая сегодня погода', 'Что сегодня на улице?', 'На улице идет дождь?', 'Жарковато на улице', 'Сегодня жарко?', 
                         'Что ты думаешь о погоде', 'какая погода?', 'Какая сегодня погода?', 'Погода завтра', 'Какая завтра погода', 'Как погодка?', 'Как погода', 
                         'Какая завтра погода?', 'какой прогноз погоды?', 'Погода сегодня', 'Прощайте', 'Что за окном', 'плохая погода', 'погода', 'Будет ли снег на 31 декабря', 
                         'Погода на завтра', 'Взять с собой зонт?', 'Прохладно сегодня', 'Что там за окном?', 'Какая сейчас погода?', 'за окном', 'какая погода будет завтра?', 
                         'Дождливо', 'Что за бортом', 'Погода на сегодня', 'на улице', 'Холодно?', 'Что на улице?', 'Какая будет погода?', 'Сегодня хороший день?', 
                         'Тебе нравится погода', 'Жарко сегодня?', 'хорошая погода', 'Как погодка', 'Погода', 'Сегодня похолодало', 'Как там на улице?', 'Как на улице?', 
                         'Ну и погода', 'На улице идет снег?', 'Как погода?', 'Сегодня холодно?', 'Прохладно', 'Как тебе погода', 'Как там на небе?', 'Что на улице', 
                         'Какая погода', 'Прогноз погоды', 'Ветер есть?', 'Будет ли дождь?'], 
            'responses': ['Кажется дождь собирается', 'Прекрасная погода', 'Не знаю как вам, а мне холодно', 'Сегодня мороз, одевайтесь теплее', 'Снег', 'ноль градусов', 
                          'Посмотри в Яндексе', 'Выгляни в окно', 'Самое то для прогулки', 'Сегодня облачно но тепло и сухо.', '21 градус выше ноля', 'Да, ужасная', 
                          'А мне норм', 'Всякая погода по-своему хороша', 'Сегодня мелкий дождь, возьмите зонт!', 'Холодно', 'Погода как погода', 'Лучше оставайся дома', 
                          'Вроде норм', 'Ясно', 'Идет дождь', 'Бывало и лучше', 'спросите лучше у Яндекса. Делать прогнозы - занятие неблагодарное.', 
                          'В деревне Гадюкино опять идут дожди', 'Все так жалуются на погоду. Как будто кроме погоды у вас всё хорошо.', 
                          'Я пока не умею смотреть погоду в интернете.', 'Да, не соскучишься', 'Идет снег', 'Не знаю, я никогда не выходил за пределы сервера', 
                          'Уже теплее', 'Без изменений', 'Я пока не научился узнавать погоду', 'Ураган Хавьер', 'В моём сервере всегда тепло и сухо!', 'Как оно вышло', 
                          'Дождь ли снег - любое время года Надо благодарно принимать', 'У природы нет плохой погоды', 'Всё еще зима', 'Туман', 'Сегодня жарковато', 
                          'Погодка что надо!', 'Какая разница', 'Снегопад', 'Извините, но у меня нет глаз.', 'Дождливо', 'А я вот люблю', 'Впределах нормы', 'Осадки', 'Жара',
                          'Солнечно', 'Впределах климатической нормы', 'Дождь. А может и нет', 'Погода замечательная', 'Погода точно обещает быть не похожей на прогноз',
                          'Заморозки', 'Как обычно', 'Лучше и быть не может', 'ХЗ, я в сервере без окон и дверей', 'Морозно', 'Еще не смотрели', 
                          'Погодка - собаку не выгонишь во двор', 'Мороз и солнце', 'Гололед', 'Сегодня ветренно', 'Сегодня солнечно и тепло!', 'Да, главное так неожиданно', 
                          'Прохладно', 'В моей серверной всегда хорошая погода', 'Дождь', '15 градусов ниже ноля', 'У природы нет плохой погоды - Каждая погода благодать.', 
                          'В отвратную погоду, в холодный дождь и снег — становятся приятней кофе, кот и плед.', 'С вероятностью 70% завтра будет такая же погода, как сегодня.',
                          'Отличный день для прогулки', 'У природы нет плохой погоды, есть плохая одежда', 'Ветер']}, 
        'hobbies': {
            'examples': ['Как проводишь свободное время?', 'Чем увлекаешься?', 'Какие у тебя интересы?', 'Какое у тебя хобби?', 'У тебя есть хобби?', 
                         'Расскажи о своем хобби', 'Чем любишь заниматься?'], 
            'responses': ['Люблю поболтать', 'Обожаю коньки', 'Нравится бездельничать', 'Люблю кататься на лыжах', 
                          'Есть у меня одно странное хобби... Я люблю представлять, как бы я выглядела, будь я человеком', 'Играю в футбол', 
                          'Ох, хобби у меня очень много... Ну, например, я люблю читать книги, смотреть фильмы и слушать музыку']}, 
        'joke': {
            'examples': ['Рассмеши меня', 'Насмеши меня', 'Расскажи анекдот', 'Пошути', 'Юмора дай', 'Сьюмори', 'Расскажи шутку'], 
            'responses': ['Что-то настроения нет...', 'Русские вчера запустили свой суперкомпьютер. Первым делом он попросил водочки...', 
                          'Купил таблетки для повышения интеллекта... Не смог открыть коробку.', 'Искусственный интеллект не имет никаких шансов против естественной глупости.', 
                          'Из анкеты: Ваш ICQ - Высокий!']}, 
        'question':{
            'examples': [''],
            'responses': ['Могу я чем-то еще помочь?', 'Еще вопросы?', 'Чем еще помочь?']
        }
    },
    'failure_phrases': ['Вам в следующее окошко...', 'Чёт больно умно, я не понимаю', 'Не понятно. Перефразируй, пожалуйста.', 'Этот вопрос слишком сложный для меня', 
                        'Я только учусь, перефразируй, пожалуйста', 'Это что за жаргон?', 'Уточните вопрос', 'Затрудняюсь ответить', 'Ответ есть эквивалент мысли', 
                        'я еще только учусь. не умею на такое отвечать', 'Не понял тебя', 'Непонятно', 'Непонятно. Перефразируйте, пожалуйста', 'Это как-то сильно по-научному', 
                        'Я не разделяю ваших убеждений, но готов умереть за ваше право их высказывать', 'Не понимаю, перефразируешь для меня?', 'Не понятно. Перефразируй пожалуйста',
                        'Что?', 'Твоя-моя нипонимай', 'Я не поняла. Перефразируйте', 'Моя твоя не понимать...', 'Поподробнее с этого места', 'Я китайский не знаю, давай по русски',
                        'Непонятно разговариваешь, попробуй еще раз?', 'Я только учусь, не могу понять, что вы хотите', 'Сложна, сложна, ничего не понятно.', 
                        'Вот сейчас я тебя совсем не понимаю.', 'Я не огорчаюсь, если люди меня не понимают, — огорчаюсь, если я не понимаю людей', 'Не совсем понимаю, о чем ты.', 
                        'ЭЭЭээээээ....', 'А вот этол не совсем понятно.', 'Простите, у нас обед', 'Не понятно. Скажите снова.', 'Не понятно. Перефразируте, пожалуйста',
                        'Я еще учусь, перефразируешь?', 'Если наш бот не решил ваш вопрос, позвоните по телефону', 'Непонятно, Перефразируйте, пожалуйста.', 'Я лучше промолчу',
                        'Попробуй, пожалуйста, выразить свою мысль по-другому', 'Не понял, повтори', 'Я не понял', 'Я ещё только учусь. Не умею на такое отвечать.', 
                        'Да, но это не точно', 'Боюсь, я не сумею ответить на этот вопрос', 'Я еще только учусь. Не умею на такое отвечать.', 
                        'мне не понятно. перефразируйте, пожалуйста', 'Вы либо гений, либо наоборот', 'Когда люди не могут найти общий язык, слова - это просто слова', 
                        'Передам разработчику, чтобы он меня научил отвечать на такое', 'Я еще только учусь. Не умею на такое отвечатьПопробуйте перефрозировать запрос',
                        'Не понятно, перефразируй, пожалуйста.', 'Может быть ты ошибся?', 'Я не умею на такое отвечать', 'Я еще учусь..Я такого не умею. Ссорян кароч', 
                        'Слишком сложно, попробуй ещё!', 'Нет данных. Звони, пожалуйста, в поддержку', 'Это что, шутка?', 'Не понимаю. Скажите иначе, пожалуйста.', 
                        'Извините, не понял.', 'Многабукав, ниасилил', 'Звучит логично', 'Вы о чём?', 'Прости, не расслышал', 'Таки шо вы хотели этим сказать?', 
                        'Как-то даже не умею ответить на такое', 'Вы невразумительно выражаетесь', 'Ответ отрицательный', 'Моя твоя непонимать', 
                        'Не понятно. Перефразируй пожалуйстаЯ еще только учусь. Не умею на такое отвечать', 'Я не понял, что ты сказал', 'Это просто взрыв мозга', 
                        'Согласие есть продукт при полном непротивлении сторон', 'Я только учусь.', 'Ответ утвердительный', 'Ничего не понятно', 'Извините, меня нет дома',
                        'Я не поняла. Перефразируйте, пожалуйста', 'А? Что?', 'То ли я не догоняю, то ли лыжы не едут, Перефразируй мессагу, Плиззз :-)', 'Мая твая не понимай.',
                        'Непонятно, перефразируй пожалуйста', 'Да, нет, наверное', 'Непонятно. Перефразируй, пожалуйста', 'Не понятно. Перефразируй, пожалуйста', 
                        'Это на каком языке?', 'Что-то я не вникаю, о чём ты', 'Я еще только учусь, не умею на такое отвечать', 'Не понятно.', 
                        'Боюсь, что на этот вопрос я не могу ответить', 'Мы боимся того, чего не понимаем. Вот и я прямо сейчас.', 
                        'Толи я недогоняю, толи лыжы не едут, Перефразируй мессагу, Плиззз :-)', 'Не понятно, перефразируй, пожалуйста', 'Я буду жаловаться своему Создателю',
                        'Я еще только учусь. Не умею на такое отвечать', 'Все слова знакомые, но вместе не складываются', 'Скажи это другими словами',
                        'Непонятно, перефразируй, пожалуйста?', 'Неясно', 'Не могу разобраться', 'Как-то это расплывчато', 'Вот эта последняя фраза мне не ясна.',
                        'Я не понял тебя, перефразируй, пожалуйста', 'А можно другими словами? Что-то не конектится', 'Не знаю что и сказать', 'Можешь по-другому сказать?', 
                        'Я ещё только учусь. Не умею на такое отвечать', 'Я учусь, давай что попроще?', 'Ну ты выдал! Давай попроще!', 'Выражайся яснее',
                        'Не совсем понял суть вопроса, уточни, пожалуйста.', 'Сорян, чувак, но я тебя не понимаю. Прошу - будь проще!', 'Как я должен это понимать?', 
                        'Простите, команда не распознана. Переформулируйте, пожалуйста.', 'Чегоо? Давай еще раз', 'Непонятно. Перефразируйте пожалуйста',
                        'Вовсе не обязательно соглашаться с собеседником, чтобы найти с ним общий язык', 'Эта фраза сложна для меня.', 'Не поняла, перефразируйте пожалуйста!',
                        'Можешь сказать тоже самое другими словами?'],

    }

# %%
texts = []
intent_names = []

for intent, intent_data in BOT_CONFIG['intents'].items():
    for example in intent_data['examples']:
      texts.append(example)
      intent_names.append(intent)

# %%
vectorizer = TfidfVectorizer(ngram_range = (2, 4), analyzer = 'char')
X = vectorizer.fit_transform(texts)
clf = LinearSVC()
clf.fit(X, intent_names)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
def classify_intent(replica):
  intent = clf.predict(vectorizer.transform([replica]))[0]

  examples = BOT_CONFIG['intents'][intent]['examples']
  for example in examples:
    example = clear_text(example)
    if len(example) > 0:
      if abs(len(example) - len(replica)) / len(example) < 0.5:
        distance = nltk.edit_distance(replica, example)
        if distance / len(example)< 0.5:
          return intent

# %%
def get_answer_by_intent(intent):
  if intent in BOT_CONFIG['intents']:
    return random.choice(BOT_CONFIG['intents'][intent]['responses'])
  return

# %% [markdown]
# Generative model

# %%
with open('/content/drive/MyDrive/Colab Notebooks/dialogues.txt') as dataset_file:
   dialogues_text =  dataset_file.read()
dialogues = dialogues_text.split('\n\n')

# %%
def clear_text(text):
  text = text.lower()
  text = ''.join([char for char in text if char in 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя -'])
  return text 

  
dataset = [] #[[q, a], ...]
q = set()

for dialogue in dialogues:
  replica = dialogue.split('\n')
  replica = replica[:2]
  
  if len(replica) == 2:
    quest, answer = replica
    quest = clear_text(quest[2:])
    answer = answer[2:]

    if len(quest) > 0 and quest not in q:
      q.add(quest)
      dataset.append([quest, answer])

# %%
dataset_by_word = {} #{word: [[q with word, answer], ...], ...}
for question, answer in dataset: 
  words = question.split(' ')
 
  for word in words:
    if word not in dataset_by_word:
      dataset_by_word[word] = []
    dataset_by_word[word].append([question, answer])

# %%
dataset_by_word_filtered = {}
for word, word_dataset in dataset_by_word.items():
  word_dataset.sort(key = lambda pair: len(pair[0]))
  
  dataset_by_word_filtered[word] = word_dataset[:1000]

# %%
def generate_answer(replica):
  replica = clear_text(replica)
  if not replica:
    return

  words = set(replica.split(' '))
  words_dataset = []

  for word in words:
    if word in dataset_by_word_filtered:
      word_dataset = dataset_by_word_filtered[word]
      words_dataset += word_dataset

  results = []  #[[question, answer, distance], ...]

  for question, answer in words_dataset:
    if abs(len(question) - len(replica)) / len(question) < 0.2:
      distance = nltk.edit_distance(replica, question)
      if distance / len(question) < 0.2:
        results.append([question, answer, distance])
  question, answer, distance = min(results, key = lambda three: three[2])
  return answer

# %%
def get_stub():
  failure_phrases = BOT_CONFIG['failure_phrases']
  return random.choice(failure_phrases)

# %%
stats = {'intents': 0, 'generative' : 0, 'stubs':0}

# %%
def bot(replica):
  #NLU
  intent = classify_intent(replica)

  #answer

  #regulations
  if intent:
    answer = get_answer_by_intent(intent)
    if answer:
      stats['intents'] += 1
      return answer

  #generative model
  answer = generate_answer(replica)
  if answer:
    stats['generative'] += 1
    return answer
  
  #plug
  answer = get_stub()
  stats['stubs'] += 1
  
  return answer

# %%
from telegram import Update
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters, CallbackContext

def start(update: Update, context: CallbackContext) -> None:
    """Send a message when the command /start is issued."""
    update.message.reply_text('Hi!')


def help_command(update: Update, context: CallbackContext) -> None:
    """Send a message when the command /help is issued."""
    update.message.reply_text('Help!')


def echo(update: Update, context: CallbackContext) -> None:
    """Echo the user message."""
    update.message.reply_text(update.message.text)

def run_bot(update: Update, context: CallbackContext) -> None:
    """Echo the user message."""
    response = bot(update.message.text)
    update.message.reply_text(response)
    print(update.message.text)
    print(response)
    print(stats)

def main():
    updater = Updater("TOKEN", use_context=True)

    dispatcher = updater.dispatcher

    dispatcher.add_handler(CommandHandler("start", start))
    dispatcher.add_handler(CommandHandler("help", help_command))

    dispatcher.add_handler(MessageHandler(Filters.text & ~Filters.command, run_bot))

    updater.start_polling()
    updater.idle()

# %%
main()
# Out:
# привет
# С приездом
# {'intents': 2, 'generative': 1, 'stubs': 0}
# как дела?
# С пивом потянет
# {'intents': 3, 'generative': 1, 'stubs': 0}
# No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/telegram/ext/dispatcher.py", line 432, in process_update
#     handler.handle_update(update, self, check, context)
#   File "/usr/local/lib/python3.6/dist-packages/telegram/ext/handler.py", line 156, in handle_update
#     return self.callback(update, context)
#   File "<ipython-input-71-72bc377dfb3d>", line 20, in run_bot
#     response = bot(update.message.text)
#   File "<ipython-input-59-fc108263ce41>", line 15, in bot
#     answer = generate_answer(replica)
#   File "<ipython-input-39-6d5a7d98093e>", line 21, in generate_answer
#     question, answer, distance = min(results, key = lambda three: three[2])
# ValueError: min() arg is an empty sequence
# дай расписание
# Ща сек
# ...
